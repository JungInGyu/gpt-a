# %% [markdown]
# # <font color='blue'> **1. Getting Started with pandas**
# # <font color='brown'> **The Machine Learning Process and Azure ML**
# ## **Workflow**
# <img src= 'https://912556475-files.gitbook.io/~/files/v0/b/gitbook-legacy-files/o/assets%2F-LxEH5JsS0dPf0_ZuSqD%2F-M1wiuy398NBw5hRkvvv%2F-M1wj99fwHoLQ4kNR5jW%2FSlide2.PNG?alt=media&token=ac4952bb-595b-4acf-8280-6814076c50bd' height=400>
#
# ## **Data Roles**
# <img src = 'https://912556475-files.gitbook.io/~/files/v0/b/gitbook-legacy-files/o/assets%2F-LxEH5JsS0dPf0_ZuSqD%2F-M1wiuy398NBw5hRkvvv%2F-M1wkLWXAAmhj46l7LWm%2FSlide3.PNG?alt=media&token=73a1ce17-f50f-4eae-b822-6509a0187dd1' height=400>
#
# - https://adnanhashmi.gitbook.io/azureml-service/section-1-introduction/the-ml-process

# %% [markdown]
# ### Step 1. 아래 코드 수행하고 '런타임 다시 시작'

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %% [markdown]
# ### Step 2. 파일을 구글에 upload

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 3. 실습파일 merge

# %%
import glob
glob.glob('*.csv')
# Out:
# ['도로교통공단_사망교통사고정보(2019).csv',
#  '도로교통공단_사망 교통사고 정보_20211231 (3).csv',
#  '도로교통공단_전국_사망교통사고_2017.csv',
#  '도로교통공단_사망교통사고정보(2020).csv',
#  '도로교통공단_전국_사망교통사고정보(2015).csv',
#  '도로교통공단_전국_사망교통사고(2016년).csv',
#  '2012_2014_교통사망사고정보.csv']

# %%
mycol = []
for file in glob.glob('*.csv'):
    df = pd.read_csv(file,  encoding='cp949')
    print(df.shape)
    mycol.append(df.columns)
# Out:
# (3233, 23)
# (2816, 23)
# (4065, 27)
# (2983, 23)
# (4447, 26)
# (4119, 27)
# (14624, 27)

# %%
mycol
# Out:
# [Index(['발생년', '발생년월일시', '주야', '요일', '사망자수', '부상자수', '중상자수', '경상자수', '부상신고자수',
#         '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '사고유형', '가해자법규위반',
#         '도로형태_대분류', '도로형태', '가해자_당사자종별', '피해자_당사자종별', '발생위치X_UTMK',
#         '발생위치Y_UTMK', '경도', '위도'],
#        dtype='object'),
#  Index(['발생년', '발생년월일시', '주야', '요일', '사망자수', '부상자수', '중상자수', '경상자수', '부상신고자수',
#         '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '사고유형', '가해자법규위반',
#         '도로형태_대분류', '도로형태', '가해자_당사자종별', '피해자_당사자종별', '발생위치X(UTMK)',
#         '발생위치Y(UTMK)', '경도', '위도'],
#        dtype='object'),
#  Index(['발생년', '발생년월일시', '발생분', '주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수',
#         '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '사고유형', '법규위반_대분류',
#         '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_1당', '당사자종별_2당_대분류',
#         '당사자종별_2당', '발생위치X_UTMK', '발생위치Y_UTMK', '경도', '위도'],
#        dtype='object'),
#  Index(['발생년', '발생년월일시', '주야', '요일', '사망자수', '부상자수', '중상자수', '경상자수', '부상신고자수',
# ...

# %% [markdown]
# - '도로교통공단_전국_사망교통사고정보(2015).csv' : '발생분' 컬럼없음

# %%
csv_files = glob.glob('*.csv')
[csv_files[i] for i in range(len(csv_files)) if i in [0, 1, 3]]
# Out:
# ['도로교통공단_사망교통사고정보(2019).csv',
#  '도로교통공단_사망 교통사고 정보_20211231 (3).csv',
#  '도로교통공단_사망교통사고정보(2020).csv']

# %%
df = pd.DataFrame()
for file in [csv_files[i] for i in range(len(csv_files)) if i in [0, 1, 3]]:
     tf = pd.read_csv(file,  encoding='cp949')
     print(tf.columns, tf.shape)
     df = df.append(tf)

df.columns, df.shape
# Out:
# Index(['발생년', '발생년월일시', '주야', '요일', '사망자수', '부상자수', '중상자수', '경상자수', '부상신고자수',
#        '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '사고유형', '가해자법규위반',
#        '도로형태_대분류', '도로형태', '가해자_당사자종별', '피해자_당사자종별', '발생위치X_UTMK',
#        '발생위치Y_UTMK', '경도', '위도'],
#       dtype='object') (3233, 23)
# Index(['발생년', '발생년월일시', '주야', '요일', '사망자수', '부상자수', '중상자수', '경상자수', '부상신고자수',
#        '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '사고유형', '가해자법규위반',
#        '도로형태_대분류', '도로형태', '가해자_당사자종별', '피해자_당사자종별', '발생위치X(UTMK)',
#        '발생위치Y(UTMK)', '경도', '위도'],
#       dtype='object') (2816, 23)
# Index(['발생년', '발생년월일시', '주야', '요일', '사망자수', '부상자수', '중상자수', '경상자수', '부상신고자수',
#        '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '사고유형', '가해자법규위반',
#        '도로형태_대분류', '도로형태', '가해자_당사자종별', '피해자_당사자종별', '발생위치X_UTMK',
#        '발생위치Y_UTMK', '경도', '위도'],
#       dtype='object') (2983, 23)
# ...

# %%
df.drop(columns = ['발생위치X(UTMK)', '발생위치Y(UTMK)', 
                   '발생위치X_UTMK',  '발생위치Y_UTMK'], inplace=True)

# %%
df.columns
# Out:
# Index(['발생년', '발생년월일시', '주야', '요일', '사망자수', '부상자수', '중상자수', '경상자수', '부상신고자수',
#        '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '사고유형', '가해자법규위반',
#        '도로형태_대분류', '도로형태', '가해자_당사자종별', '피해자_당사자종별', '경도', '위도'],
#       dtype='object')

# %%
df.head()
# Out:
#     발생년         발생년월일시 주야 요일  사망자수  부상자수  중상자수  경상자수  부상신고자수 발생지시도  ...  \
# 0  2019  2019-01-01 00  야  화     1     0     0     0       0    부산  ...
# 1  2019  2019-01-01 03  야  화     1     0     0     0       0    경기  ...
# 2  2019  2019-01-01 16  주  화     1     0     0     0       0    경북  ...
# 3  2019  2019-01-01 19  야  화     1     0     0     0       0    대전  ...
# 4  2019  2019-01-01 21  야  화     1     0     0     0       0    경북  ...
#
#   사고유형_대분류 사고유형_중분류  사고유형      가해자법규위반 도로형태_대분류   도로형태 가해자_당사자종별    피해자_당사자종별  \
# 0     차대사람       기타    기타       중앙선 침범      교차로   교차로내       승용차          보행자
# 1      차대차     정면충돌  정면충돌       중앙선 침범      단일로  기타단일로       승용차          승용차
# 2      차대차     측면충돌  측면충돌  안전운전 의무 불이행      교차로  교차로부근       승용차  사륜오토바이(ATV)
# 3     차대사람      횡단중   횡단중  안전운전 의무 불이행      교차로  교차로부근       승용차          보행자
# 4     차대사람       기타    기타  안전운전 의무 불이행      단일로  기타단일로       승용차          보행자
#
#            경도         위도
# 0  129.152465  35.157884
# ...

# %%
df.발생년.value_counts()
# Out:
# 2019    3233
# 2020    2983
# 2021    2816
# Name: 발생년, dtype: int64

# %%
df1 = df.copy()

# %%
[csv_files[i] for i in range(len(csv_files)) if i in [2, 4, 5, 6]]
files = [csv_files[i] for i in range(len(csv_files)) if i in [2, 4, 5, 6]]
files
# Out:
# ['도로교통공단_전국_사망교통사고_2017.csv',
#  '도로교통공단_전국_사망교통사고정보(2015).csv',
#  '도로교통공단_전국_사망교통사고(2016년).csv',
#  '2012_2014_교통사망사고정보.csv']

# %%
df = pd.DataFrame()
for file in files:
     tf = pd.read_csv(file,  encoding='cp949')
     print(tf.columns, tf.shape)
     df = df.append(tf)

df.columns, df.shape
# Out:
# Index(['발생년', '발생년월일시', '발생분', '주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수',
#        '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '사고유형', '법규위반_대분류',
#        '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_1당', '당사자종별_2당_대분류',
#        '당사자종별_2당', '발생위치X_UTMK', '발생위치Y_UTMK', '경도', '위도'],
#       dtype='object') (4065, 27)
# Index(['발생년', '발생년월일시분', '주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수',
#        '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '사고유형', '법규위반_대분류', '법규위반',
#        '도로형태_대분류', '도로형태', '가해자_당사자종별_대분류', '가해자_당사자종별', '피해자_당사자종별_대분류',
#        '피해자_당사자종별', '발생위치X_UTMK', '발생위치Y_UTMK', '경도', '위도'],
#       dtype='object') (4447, 26)
# Index(['발생년', '발생년월일시', '발생분', '주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수',
#        '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '사고유형', '법규위반_대분류',
#        '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_1당', '당사자종별_2당_대분류',
#        '당사자종별_2당', '발생위치X_UTMK', '발생위치Y_UTMK', '경도', '위도'],
# ...

# %%
df.columns
# Out:
# Index(['발생년', '발생년월일시', '발생분', '주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수',
#        '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '사고유형', '법규위반_대분류',
#        '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_1당', '당사자종별_2당_대분류',
#        '당사자종별_2당', '발생위치X_UTMK', '발생위치Y_UTMK', '경도', '위도', '발생년월일시분',
#        '가해자_당사자종별_대분류', '가해자_당사자종별', '피해자_당사자종별_대분류', '피해자_당사자종별'],
#       dtype='object')

# %%
df.drop(columns=['발생위치X_UTMK', '발생위치Y_UTMK', '발생년월일시분',
       '가해자_당사자종별_대분류', '가해자_당사자종별', '피해자_당사자종별_대분류', '피해자_당사자종별']).head()
# Out:
#     발생년            발생년월일시   발생분  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수  ...  \
# 0  2017  2017-01-01 01:00  15.0  야간  일     1     2     1     0       0  ...
# 1  2017  2017-01-01 02:00  28.0  야간  일     1     1     0     0       0  ...
# 2  2017  2017-01-01 02:00  43.0  야간  일     1     2     0     1       0  ...
# 3  2017  2017-01-01 02:00  22.0  야간  일     1     1     0     0       0  ...
# 4  2017  2017-01-01 04:00  37.0  야간  일     1     1     0     0       0  ...
#
#   법규위반_대분류         법규위반 도로형태_대분류   도로형태 당사자종별_1당_대분류 당사자종별_1당 당사자종별_2당_대분류  \
# 0  운전자법규위반  안전운전 의무 불이행      단일로  기타단일로          승용차      승용차          승용차
# 1  운전자법규위반  안전운전 의무 불이행      교차로  교차로부근          승용차      승용차          보행자
# 2  운전자법규위반  안전운전 의무 불이행      단일로  기타단일로          승용차      승용차          승용차
# 3  운전자법규위반  안전운전 의무 불이행      단일로  기타단일로          승용차      승용차           없음
# 4  운전자법규위반  안전운전 의무 불이행      단일로  기타단일로          승용차      승용차          보행자
#
#   당사자종별_2당          경도         위도
# ...

# %%
import missingno as msn
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic') 

data = df.drop(columns=['발생위치X_UTMK', '발생위치Y_UTMK', '발생년월일시분',
       '가해자_당사자종별_대분류', '가해자_당사자종별', '피해자_당사자종별_대분류', '피해자_당사자종별'])
msn.matrix(data)
# Out:
# <Axes: >

# %%
tf.columns
# Out:
# Index(['발생년', '발생년월일시', '발생분', '주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수',
#        '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '사고유형', '법규위반_대분류',
#        '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_1당', '당사자종별_2당_대분류',
#        '당사자종별_2당', '발생위치X_UTMK', '발생위치Y_UTMK', '경도', '위도'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['발생년', '발생년월일시', '발생분', '주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수',
#        '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '사고유형', '법규위반_대분류',
#        '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_1당', '당사자종별_2당_대분류',
#        '당사자종별_2당', '경도', '위도'],
#       dtype='object')

# %%
del tf['발생위치X_UTMK']
del tf['발생위치Y_UTMK']

# %%
tf.columns
# Out:
# Index(['발생년', '발생년월일시', '발생분', '주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수',
#        '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '사고유형', '법규위반_대분류',
#        '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_1당', '당사자종별_2당_대분류',
#        '당사자종별_2당', '경도', '위도'],
#       dtype='object')

# %%
import warnings
warnings.filterwarnings('ignore')
df = data.append(tf)

# %%
df.shape
# Out:
# (41879, 25)

# %% [markdown]
# ### Step 4. 완성된 merged 파일을 자장하고 로컬로 다운로드

# %%
df.to_excel('실습파일.xlsx')

# %%
df.to_pickle('실습파일.pkl')

# %% [markdown]
# # End

# %%
# %time pd.read_excel('실습파일.xlsx')
# Out:
# CPU times: user 19.8 s, sys: 56.3 ms, total: 19.9 s
# Wall time: 22.6 s
#        Unnamed: 0   발생년            발생년월일시   발생분  주야 요일  사망자수  사상자수  중상자수  \
# 0               0  2017  2017-01-01 01:00  15.0  야간  일     1     2     1
# 1               1  2017  2017-01-01 02:00  28.0  야간  일     1     1     0
# 2               2  2017  2017-01-01 02:00  43.0  야간  일     1     2     0
# 3               3  2017  2017-01-01 02:00  22.0  야간  일     1     1     0
# 4               4  2017  2017-01-01 04:00  37.0  야간  일     1     1     0
# ...           ...   ...               ...   ...  .. ..   ...   ...   ...
# 41874       14619  2014  2014-07-05 16:00  30.0  주간  토     1     1     0
# 41875       14620  2014  2014-07-12 18:00  20.0  야간  토     1     8     2
# 41876       14621  2014  2014-07-15 04:00  30.0  야간  화     2     6     2
# 41877       14622  2014  2014-07-10 20:00  40.0  야간  목     1     3     0
# 41878       14623  2014  2014-07-20 10:00  20.0  주간  일     1     1     0
#
# ...

# %%
# %time pd.read_pickle('실습파일.pkl')
# Out:
# CPU times: user 23.1 ms, sys: 1.98 ms, total: 25.1 ms
# Wall time: 26.6 ms
#         발생년            발생년월일시   발생분  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수  \
# 0      2017  2017-01-01 01:00  15.0  야간  일     1     2     1     0       0
# 1      2017  2017-01-01 02:00  28.0  야간  일     1     1     0     0       0
# 2      2017  2017-01-01 02:00  43.0  야간  일     1     2     0     1       0
# 3      2017  2017-01-01 02:00  22.0  야간  일     1     1     0     0       0
# 4      2017  2017-01-01 04:00  37.0  야간  일     1     1     0     0       0
# ...     ...               ...   ...  .. ..   ...   ...   ...   ...     ...
# 14619  2014  2014-07-05 16:00  30.0  주간  토     1     1     0     0       0
# 14620  2014  2014-07-12 18:00  20.0  야간  토     1     8     2     5       0
# 14621  2014  2014-07-15 04:00  30.0  야간  화     2     6     2     2       0
# 14622  2014  2014-07-10 20:00  40.0  야간  목     1     3     0     2       0
# ...
